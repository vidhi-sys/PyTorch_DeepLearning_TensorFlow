# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhi-sys/PyTorch_DeepLearning_TensorFlow/blob/main/linear_regression_w_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# https://www.google.com/search?q=broadcasting+in+pytorch&oq=broadcasting+in+pytorch&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIGCAEQLhhA0gEINTA2M2owajGoAgCwAgA&sourceid=chrome&ie=UTF-8

# %%
a=np.array([[2,3,4],[3,5,7]],dtype=float)
x=torch.from_numpy(a).float()#input

# %%
y = torch.tensor([[5.0, 12.0], [7.0, 15.0]]) # Example target output

output = model(x)
difference = output - y

print("Model Output:\n", output)
print("\nTarget Output:\n", y)
print("\nDifference:\n", difference)

plt.figure(figsize=(8, 6))
plt.imshow(difference.detach().numpy(), cmap='coolwarm', aspect='auto')
plt.colorbar(label='Difference')
plt.title('Difference between Model Output and Target Output')
plt.xlabel('Output Dimension')
plt.ylabel('Input Sample')
plt.show()
# Out:
# Model Output:
#  tensor([[ 4.3117, -0.2043],
#         [ 5.9466,  0.8100]], grad_fn=<AddBackward0>)
#
# Target Output:
#  tensor([[ 5., 12.],
#         [ 7., 15.]])
#
# Difference:
#  tensor([[ -0.6883, -12.2043],
#         [ -1.0534, -14.1900]], grad_fn=<SubBackward0>)

# %%
w=torch.randn(2,3,requires_grad=True)

b=torch.randn(2,requires_grad=True)

# %%
def model(X):
  return X @ w.t()+b

# %%
print(model(x))
# Out:
# tensor([[ 4.3117, -0.2043],
#         [ 5.9466,  0.8100]], grad_fn=<AddBackward0>)
